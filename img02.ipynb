# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("57515.jpg")

# %%
img.shape
# Out:
# (520, 406, 3)

# %%
plt.imshow(img[...,::-1])

# %%
b,g,r = cv2.split(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img1 = np.where(img==255, 0,img)

# %%
plt.imshow(img1[...,::-1])

# %%
forth_chan = np.zeros((520,406),np.uint8)
forth_chan = np.where(b==255,0,255)

# %%
plt.imshow(forth_chan, cmap = 'gray')

# %%
png_img = np.zeros((520,406,4),np.uint8)

# %%
png_img[:,:,0:3] = img

# %%
png_img[:,:,3] = forth_chan

# %%
cv2.imwrite("my.png",png_img)
# Out:
# True
